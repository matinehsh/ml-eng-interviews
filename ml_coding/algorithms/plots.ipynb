# %%
from collections import defaultdict
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.hist(np.random.randn(1000,2)); # each dim is normal

# %%
x1 = np.random.randn(150,1) + 10
x2 = np.random.randn(150,1) - 10
x3 = np.random.randn(150,1)
data1 = np.vstack((x1, x2, x3))
data2 = np.vstack((x1*0.5, x2*0.5, x3+2))

d
